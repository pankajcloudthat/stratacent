# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('literary_birth_rate.csv', sep=';')

# %%
df.head()
# Out:
#     Country  Continent  literacy  fertility     population
# 0      Chine       ASI      90.5      1.769  1,324,655,000
# 1       Inde       ASI      50.8      2.682  1,139,964,932
# 2        USA       NAM      99.0      2.077    304,060,000
# 3  Indonésie       ASI      88.8      2.132    227,345,082
# 4     Brésil       LAT      90.2      1.827    191,971,506

# %%
df.tail(5)
# Out:
#                  Country  Continent  literacy  fertility population
# 157               Vanuatu       OCE      79.5      3.883    233,866
# 158                 Samoa       OCE      98.5      3.852    178,869
# 159  Sao Tomé-et-Principe        AF      83.3      3.718    160,174
# 160                 Aruba       LAT      98.0      1.732    105,455
# 161                 Tonga       ASI      99.1      3.928    103,566

# %%
df.columns
# Out:
# Index(['Country ', 'Continent', 'literacy', 'fertility', 'population'], dtype='object')

# %%
df = df.rename(columns={'Country ':'country',})
df.columns
# Out:
# Index(['country', 'Continent', 'literacy', 'fertility', 'population'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     162 non-null    object
#  1   Continent   162 non-null    object
#  2   literacy    162 non-null    float64
#  3   fertility   162 non-null    float64
#  4   population  162 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 6.5+ KB

# %%
df.describe()
# Out:
#        female literacy   fertility
# count       162.000000  162.000000
# mean         80.107407    2.878673
# std          23.052415    1.427597
# min          12.600000    0.966000
# 25%          66.425000    1.823250
# 50%          90.000000    2.367500
# 75%          98.500000    3.880250
# max         100.000000    7.069000

# %%
df.Continent.value_counts(dropna=False)
# Out:
# AF     49
# ASI    47
# EUR    36
# LAT    24
# OCE     4
# NAM     2
# Name: Continent, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
df.Continent.value_counts().plot(kind='bar')
plt.title("value count of Continent")
plt.xlabel("Continent")
plt.ylabel("Count")
plt.show()

# %%
df.fertility.describe()
# Out:
# count    162.000000
# mean       2.878673
# std        1.427597
# min        0.966000
# 25%        1.823250
# 50%        2.367500
# 75%        3.880250
# max        7.069000
# Name: fertility, dtype: float64

# %%
df.fertility.plot(kind='hist')
plt.show()

# %%
df.fertility.skew()
# Out:
# 0.9025134422039927

# %%
df.fertility.kurt()
# Out:
# -0.24170934720429216

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue='Continent')

# %%
sns.scatterplot(x="literacy", y="fertility", hue='Continent', data=df, s=80)
# plt.title("Boxplot for target vs proline")
plt.show()
